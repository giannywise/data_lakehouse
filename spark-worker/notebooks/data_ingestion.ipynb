# %%
# SparkSession
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType
import os
from pyspark.sql.functions import *
from delta import configure_spark_with_delta_pip
from delta.tables import DeltaTable

spark = SparkSession.builder \
    .appName("lakehouse") \
    .master("spark://spark-master:7077") \
    .config("spark.delta.columnMapping.mode", "name") \
    .config("spark.sql.catalogImplementation","hive") \
    .config("spark.sql.warehouse.dir","s3a://hive/") \
    .config("spark.sql.hive.metastore.version","3.1.3") \
    .config("spark.sql.hive.metastore.jars","path") \
    .config("spark.sql.hive.metastore.jars.path","file:///opt/spark/hive/jars/*") \
    .config("spark.sql.legacy.charVarcharAsString", True) \
    .config("spark.sql.sources.partitionOverwriteMode", "dynamic") \
    .config("hive.metastore.warehouse.dir","s3a://hive/") \
    .config("spark.hive.metastore.schema.verification","false") \
    .config("hive.exec.dynamic.partition", "true") \
    .config("hive.exec.dynamic.partition.mode", "nonstrict") \
    .enableHiveSupport() \
    .getOrCreate()

# Minimierung des LOGS
spark.sparkContext.setLogLevel("ERROR")
log4jLogger = spark._jvm.org.apache.log4j
logger = log4jLogger.LogManager.getLogger("LOGGER")
logger.setLevel(log4jLogger.Level.INFO)
# Out:
# Warning: Ignoring non-Spark config property: hive.exec.dynamic.partition.mode
# Warning: Ignoring non-Spark config property: hive.metastore.warehouse.dir
# Warning: Ignoring non-Spark config property: hive.exec.dynamic.partition
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-9d370e67-3fbc-499d-b6b4-63abc7e99ca4;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.3.0 in central
# 	found io.delta#delta-storage;3.3.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# downloading https://repo1.maven.org/maven2/io/delta/delta-spark_2.12/3.3.0/delta-spark_2.12-3.3.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-spark_2.12;3.3.0!delta-spark_2.12.jar (322ms)
# downloading https://repo1.maven.org/maven2/io/delta/delta-storage/3.3.0/delta-storage-3.3.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-storage;3.3.0!delta-storage.jar (62ms)
# downloading https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.9.3/antlr4-runtime-4.9.3.jar ...
# 	[SUCCESSFUL ] org.antlr#antlr4-runtime;4.9.3!antlr4-runtime.jar (44ms)
# :: resolution report :: resolve 1359ms :: artifacts dl 432ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.3.0 from central in [default]
# 	io.delta#delta-storage;3.3.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   3   |   3   |   0   ||   3   |   3   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-9d370e67-3fbc-499d-b6b4-63abc7e99ca4
# 	confs: [default]
# 	3 artifacts copied, 0 already retrieved (7313kB/14ms)
# 25/02/22 17:20:42 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
# Datenaufnahme
directory = "data/"
ignore_file = ".DS_Store"

# Liste, um die Namen zu sammeln
names = []

# For-Loop, um durch den Verzeichnisinhalt zu iterieren und nur die Namen zu erfassen
for entry in os.scandir(directory):
    # Ignoriere die Datei ".DS_Store"
    if entry.name == ignore_file:
        continue
    # Überprüfen, ob der Dateiname mit ".db" endet
    if entry.name.endswith(".db"):
        # Endung entfernen
        name_without_extension = os.path.splitext(entry.name)[0]
        names.append((name_without_extension,))
    else:
        # Anderenfalls den Originalnamen verwenden
        names.append((entry.name,))

df_file_list = spark.createDataFrame(names, ["name"])

for row in df_file_list.collect():
    DB_NAME = row["name"]
    spark.sql(f"CREATE DATABASE IF NOT EXISTS {DB_NAME}")
    spark.sql(f'USE {DB_NAME}')

    # Verwende einen relativen Pfad und konvertiere in einen absoluten Pfad:
    relative_path = f"data/{DB_NAME}.db"
    absolute_path = os.path.abspath(relative_path)
    jdbc_url = f"jdbc:sqlite:{absolute_path}"

    table_names = [row["name"] for row in df_tables.collect()]
    #print(f"{DB_NAME} Started!")
    for TABLE_NAME in table_names:
        #print(f"{TABLE_NAME} Started!")
        df = spark.read.format("jdbc").option("url", jdbc_url).option("dbtable", TABLE_NAME).option("driver", "org.sqlite.JDBC").load()
        spark.sql(f"DROP DATABASE IF EXISTS {TABLE_NAME} cascade") # Löscht den MetaStore Eintrag
        df.write.format("delta").mode("overwrite").option("path", f's3a://bronze/fidus/{DB_NAME}/{TABLE_NAME}/').saveAsTable(TABLE_NAME)
        #print(f"{TABLE_NAME} Done!")

    print(f"{DB_NAME} SUCCESS!")
print("ALL DONE!")
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# Cell In[3], line 26
#      24 for row in df_file_list.collect():
#      25     DB_NAME = row["name"]
# ---> 26     spark.sql(f"CREATE DATABASE IF NOT EXISTS {DB_NAME}")
#      27     spark.sql(f'USE {DB_NAME}')
#      29     # Verwende einen relativen Pfad und konvertiere in einen absoluten Pfad:
#
# File /usr/local/lib/python3.10/dist-packages/pyspark/sql/session.py:1631, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#    1627         assert self._jvm is not None
#    1628         litArgs = self._jvm.PythonUtils.toArray(
#    1629             [_to_java_column(lit(v)) for v in (args or [])]
#    1630         )
# -> 1631     return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1632 finally:
#    1633     if len(kwargs) > 0:
#
# File /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/lib/python3.10/dist-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# ParseException:
# [PARSE_SYNTAX_ERROR] Syntax error at or near '.'.(line 1, pos 30)
#
# == SQL ==
# CREATE DATABASE IF NOT EXISTS ._.DS_Store
# ------------------------------^^^

# %%
# Join der Datenbanken

# Liste der Datenbanken
databases = [
    "fidus_and",
    "fidus_hbs",
    "fidus_hrs",
    "fidus_mhw",
    "fidus_oaf",
    "fidus_sub",
    "fidus_sue",
    "fidus_wrw"
]

# Liste der Tabellennamen
tables = [
    "behdatei",
    "praxarzt",
    "patdat",
    "adrver",
    "begrun",
    "arbehdat",
    "rechkopf",
    "rechpos",
    "ekktexte",
    "ckeytabs",
    "patinfo"
]

# Wir bauen die temporäre View "joined_view" schrittweise auf.
joined_view = None

# Verschachtelte Schleife: Für jede Datenbank und jede Tabelle
for db in databases:
    for tbl in tables:
        full_table_name = f"{db}.{tbl}"
        print(f"Verarbeite Tabelle: {full_table_name}")

        try:
            if joined_view is None:
                # Initialen Start: Lege die erste Tabelle als temporäre View ab
                spark.sql(f"""
                    CREATE OR REPLACE TEMP VIEW joined_view AS
                    SELECT *
                    FROM {full_table_name}
                """)
                joined_view = "joined_view"
            else:
                spark.sql(f"""
                    CREATE OR REPLACE TEMP VIEW joined_view AS
                    SELECT t1.*, t2.*
                    FROM joined_view t1
                    INNER JOIN {full_table_name} t2
                    ON t1.id = t2.bsnr
                """)
        except Exception as e:
            print(f"Fehler beim Laden/Joinen von {full_table_name}: {e}")

# Finale Abfrage aus der temporären View, die alle Spalten enthalten sollte
df_final = spark.sql("SELECT * FROM joined_view")
# Out:
# Verarbeite Tabelle: fidus_and.behdatei
# Hive Session ID = d4fa367a-f18b-4392-8a36-cd3dc9dda52f
# Verarbeite Tabelle: fidus_and.praxarzt
# Fehler beim Laden/Joinen von fidus_and.praxarzt: [RECURSIVE_VIEW] Recursive view `joined_view` detected (cycle: `joined_view` -> `joined_view`).
# Verarbeite Tabelle: fidus_and.patdat
# Fehler beim Laden/Joinen von fidus_and.patdat: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`kasnr`, `t2`.`stra`, `t2`.`akm`, `t2`.`dmp`, `t2`.`egk`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_and.patdat t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#214 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#182,ksnam#183,ksgebdat#184,ksbehdat#185,kslz1#186,kslz2#187,kslz3#188,kslz4#189,kslz5#190,kslz6#191,kslz7#192,kslz8#193,kslz9#194,kslz10#195,kskas#196,ksgs#197,ksver#198,kasnr#199,kasgor#200,scheinart#201,behart#202,kvklesdatu#203,kvkgueltig#204,regkas#205,versichnr#206,iknr#207,verst#208,verste#209,ktgr#210,abrart#211,abrgebiet#212,kvkl_zulnr#213,id#214,scheinid#215,praxis#216,arzt#217,abrkennz#218,abrjjq#219,uhrzeit#220,wop#221,egk#222,personengr#223,dmp#224,vschutzvon#225,kartekas#226])
#       :        +- Project [cast(kspatnr#227 as double) AS kspatnr#182, cast(ksnam#228 as string) AS ksnam#183, cast(ksgebdat#229 as string) AS ksgebdat#184, cast(ksbehdat#230 as string) AS ksbehdat#185, cast(kslz1#231 as string) AS kslz1#186, cast(kslz2#232 as string) AS kslz2#187, cast(kslz3#233 as string) AS kslz3#188, cast(kslz4#234 as string) AS kslz4#189, cast(kslz5#235 as string) AS kslz5#190, cast(kslz6#236 as string) AS kslz6#191, cast(kslz7#237 as string) AS kslz7#192, cast(kslz8#238 as string) AS kslz8#193, cast(kslz9#239 as string) AS kslz9#194, cast(kslz10#240 as string) AS kslz10#195, cast(kskas#241 as string) AS kskas#196, cast(ksgs#242 as int) AS ksgs#197, cast(ksver#243 as string) AS ksver#198, cast(kasnr#244 as double) AS kasnr#199, cast(kasgor#245 as string) AS kasgor#200, cast(scheinart#246 as string) AS scheinart#201, cast(behart#247 as double) AS behart#202, cast(kvklesdatu#248 as string) AS kvklesdatu#203, cast(kvkgueltig#249 as string) AS kvkgueltig#204, cast(regkas#250 as string) AS regkas#205, ... 21 more fields]
#       :           +- Project [kspatnr#227, ksnam#228, ksgebdat#229, ksbehdat#230, kslz1#231, kslz2#232, kslz3#233, kslz4#234, kslz5#235, kslz6#236, kslz7#237, kslz8#238, kslz9#239, kslz10#240, kskas#241, ksgs#242, ksver#243, kasnr#244, kasgor#245, scheinart#246, behart#247, kvklesdatu#248, kvkgueltig#249, regkas#250, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#227,ksnam#228,ksgebdat#229,ksbehdat#230,kslz1#231,kslz2#232,kslz3#233,kslz4#234,kslz5#235,kslz6#236,kslz7#237,kslz8#238,kslz9#239,kslz10#240,kskas#241,ksgs#242,ksver#243,kasnr#244,kasgor#245,scheinart#246,behart#247,kvklesdatu#248,kvkgueltig#249,regkas#250,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_and.patdat
#             +- Relation spark_catalog.fidus_and.patdat[patnr#273,titel#274,name#275,vname#276,ges#277,geb#278,stra#279,lkz#280,plz#281,ort#282,remnr#283,vernr#284,ledat#285,arbeit#286,arbplz#287,arbort#288,verst#289,verste#290,kas#291,kasort#292,kasnr#293,kasgor#294,kvkgueltig#295,kvklesdatu#296,... 34 more fields] parquet
#
# Verarbeite Tabelle: fidus_and.adrver
# Fehler beim Laden/Joinen von fidus_and.adrver: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`adrbsnr`, `t2`.`adrnr`, `t1`.`id`, `t1`.`iknr`, `t1`.`kasnr`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_and.adrver t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#364 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#332,ksnam#333,ksgebdat#334,ksbehdat#335,kslz1#336,kslz2#337,kslz3#338,kslz4#339,kslz5#340,kslz6#341,kslz7#342,kslz8#343,kslz9#344,kslz10#345,kskas#346,ksgs#347,ksver#348,kasnr#349,kasgor#350,scheinart#351,behart#352,kvklesdatu#353,kvkgueltig#354,regkas#355,versichnr#356,iknr#357,verst#358,verste#359,ktgr#360,abrart#361,abrgebiet#362,kvkl_zulnr#363,id#364,scheinid#365,praxis#366,arzt#367,abrkennz#368,abrjjq#369,uhrzeit#370,wop#371,egk#372,personengr#373,dmp#374,vschutzvon#375,kartekas#376])
#       :        +- Project [cast(kspatnr#377 as double) AS kspatnr#332, cast(ksnam#378 as string) AS ksnam#333, cast(ksgebdat#379 as string) AS ksgebdat#334, cast(ksbehdat#380 as string) AS ksbehdat#335, cast(kslz1#381 as string) AS kslz1#336, cast(kslz2#382 as string) AS kslz2#337, cast(kslz3#383 as string) AS kslz3#338, cast(kslz4#384 as string) AS kslz4#339, cast(kslz5#385 as string) AS kslz5#340, cast(kslz6#386 as string) AS kslz6#341, cast(kslz7#387 as string) AS kslz7#342, cast(kslz8#388 as string) AS kslz8#343, cast(kslz9#389 as string) AS kslz9#344, cast(kslz10#390 as string) AS kslz10#345, cast(kskas#391 as string) AS kskas#346, cast(ksgs#392 as int) AS ksgs#347, cast(ksver#393 as string) AS ksver#348, cast(kasnr#394 as double) AS kasnr#349, cast(kasgor#395 as string) AS kasgor#350, cast(scheinart#396 as string) AS scheinart#351, cast(behart#397 as double) AS behart#352, cast(kvklesdatu#398 as string) AS kvklesdatu#353, cast(kvkgueltig#399 as string) AS kvkgueltig#354, cast(regkas#400 as string) AS regkas#355, ... 21 more fields]
#       :           +- Project [kspatnr#377, ksnam#378, ksgebdat#379, ksbehdat#380, kslz1#381, kslz2#382, kslz3#383, kslz4#384, kslz5#385, kslz6#386, kslz7#387, kslz8#388, kslz9#389, kslz10#390, kskas#391, ksgs#392, ksver#393, kasnr#394, kasgor#395, scheinart#396, behart#397, kvklesdatu#398, kvkgueltig#399, regkas#400, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#377,ksnam#378,ksgebdat#379,ksbehdat#380,kslz1#381,kslz2#382,kslz3#383,kslz4#384,kslz5#385,kslz6#386,kslz7#387,kslz8#388,kslz9#389,kslz10#390,kskas#391,ksgs#392,ksver#393,kasnr#394,kasgor#395,scheinart#396,behart#397,kvklesdatu#398,kvkgueltig#399,regkas#400,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_and.adrver
#             +- Relation spark_catalog.fidus_and.adrver[adrnr#423,adrtit#424,adrnam#425,adrvor#426,adrges#427,adrbez#428,adrstr#429,adrlkz#430,adrplz#431,adrort#432,adrtel#433,adrfax#434,adranr#435,adrna2#436,adrgs2#437,adrmerkmal#438,adrbsnr#439,adrlanr#440,email#441] parquet
#
# Verarbeite Tabelle: fidus_and.begrun
# Fehler beim Laden/Joinen von fidus_and.begrun: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`beg`, `t2`.`blen`, `t2`.`id`, `t2`.`kasnr`, `t1`.`id`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_and.begrun t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#475 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#443,ksnam#444,ksgebdat#445,ksbehdat#446,kslz1#447,kslz2#448,kslz3#449,kslz4#450,kslz5#451,kslz6#452,kslz7#453,kslz8#454,kslz9#455,kslz10#456,kskas#457,ksgs#458,ksver#459,kasnr#460,kasgor#461,scheinart#462,behart#463,kvklesdatu#464,kvkgueltig#465,regkas#466,versichnr#467,iknr#468,verst#469,verste#470,ktgr#471,abrart#472,abrgebiet#473,kvkl_zulnr#474,id#475,scheinid#476,praxis#477,arzt#478,abrkennz#479,abrjjq#480,uhrzeit#481,wop#482,egk#483,personengr#484,dmp#485,vschutzvon#486,kartekas#487])
#       :        +- Project [cast(kspatnr#488 as double) AS kspatnr#443, cast(ksnam#489 as string) AS ksnam#444, cast(ksgebdat#490 as string) AS ksgebdat#445, cast(ksbehdat#491 as string) AS ksbehdat#446, cast(kslz1#492 as string) AS kslz1#447, cast(kslz2#493 as string) AS kslz2#448, cast(kslz3#494 as string) AS kslz3#449, cast(kslz4#495 as string) AS kslz4#450, cast(kslz5#496 as string) AS kslz5#451, cast(kslz6#497 as string) AS kslz6#452, cast(kslz7#498 as string) AS kslz7#453, cast(kslz8#499 as string) AS kslz8#454, cast(kslz9#500 as string) AS kslz9#455, cast(kslz10#501 as string) AS kslz10#456, cast(kskas#502 as string) AS kskas#457, cast(ksgs#503 as int) AS ksgs#458, cast(ksver#504 as string) AS ksver#459, cast(kasnr#505 as double) AS kasnr#460, cast(kasgor#506 as string) AS kasgor#461, cast(scheinart#507 as string) AS scheinart#462, cast(behart#508 as double) AS behart#463, cast(kvklesdatu#509 as string) AS kvklesdatu#464, cast(kvkgueltig#510 as string) AS kvkgueltig#465, cast(regkas#511 as string) AS regkas#466, ... 21 more fields]
#       :           +- Project [kspatnr#488, ksnam#489, ksgebdat#490, ksbehdat#491, kslz1#492, kslz2#493, kslz3#494, kslz4#495, kslz5#496, kslz6#497, kslz7#498, kslz8#499, kslz9#500, kslz10#501, kskas#502, ksgs#503, ksver#504, kasnr#505, kasgor#506, scheinart#507, behart#508, kvklesdatu#509, kvkgueltig#510, regkas#511, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#488,ksnam#489,ksgebdat#490,ksbehdat#491,kslz1#492,kslz2#493,kslz3#494,kslz4#495,kslz5#496,kslz6#497,kslz7#498,kslz8#499,kslz9#500,kslz10#501,kskas#502,ksgs#503,ksver#504,kasnr#505,kasgor#506,scheinart#507,behart#508,kvklesdatu#509,kvkgueltig#510,regkas#511,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_and.begrun
#             +- Relation spark_catalog.fidus_and.begrun[kspatnr#534,kasnr#535,jjq#536,scheinart#537,begruendg1#538,beg#539,blen#540,id#541,suntergr#542,abrechnung#543,abrdatum#544] parquet
#
# Verarbeite Tabelle: fidus_and.arbehdat
# Fehler beim Laden/Joinen von fidus_and.arbehdat: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`id`, `t2`.`iknr`, `t2`.`kasnr`, `t2`.`dmp`, `t2`.`egk`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_and.arbehdat t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#578 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#546,ksnam#547,ksgebdat#548,ksbehdat#549,kslz1#550,kslz2#551,kslz3#552,kslz4#553,kslz5#554,kslz6#555,kslz7#556,kslz8#557,kslz9#558,kslz10#559,kskas#560,ksgs#561,ksver#562,kasnr#563,kasgor#564,scheinart#565,behart#566,kvklesdatu#567,kvkgueltig#568,regkas#569,versichnr#570,iknr#571,verst#572,verste#573,ktgr#574,abrart#575,abrgebiet#576,kvkl_zulnr#577,id#578,scheinid#579,praxis#580,arzt#581,abrkennz#582,abrjjq#583,uhrzeit#584,wop#585,egk#586,personengr#587,dmp#588,vschutzvon#589,kartekas#590])
#       :        +- Project [cast(kspatnr#591 as double) AS kspatnr#546, cast(ksnam#592 as string) AS ksnam#547, cast(ksgebdat#593 as string) AS ksgebdat#548, cast(ksbehdat#594 as string) AS ksbehdat#549, cast(kslz1#595 as string) AS kslz1#550, cast(kslz2#596 as string) AS kslz2#551, cast(kslz3#597 as string) AS kslz3#552, cast(kslz4#598 as string) AS kslz4#553, cast(kslz5#599 as string) AS kslz5#554, cast(kslz6#600 as string) AS kslz6#555, cast(kslz7#601 as string) AS kslz7#556, cast(kslz8#602 as string) AS kslz8#557, cast(kslz9#603 as string) AS kslz9#558, cast(kslz10#604 as string) AS kslz10#559, cast(kskas#605 as string) AS kskas#560, cast(ksgs#606 as int) AS ksgs#561, cast(ksver#607 as string) AS ksver#562, cast(kasnr#608 as double) AS kasnr#563, cast(kasgor#609 as string) AS kasgor#564, cast(scheinart#610 as string) AS scheinart#565, cast(behart#611 as double) AS behart#566, cast(kvklesdatu#612 as string) AS kvklesdatu#567, cast(kvkgueltig#613 as string) AS kvkgueltig#568, cast(regkas#614 as string) AS regkas#569, ... 21 more fields]
#       :           +- Project [kspatnr#591, ksnam#592, ksgebdat#593, ksbehdat#594, kslz1#595, kslz2#596, kslz3#597, kslz4#598, kslz5#599, kslz6#600, kslz7#601, kslz8#602, kslz9#603, kslz10#604, kskas#605, ksgs#606, ksver#607, kasnr#608, kasgor#609, scheinart#610, behart#611, kvklesdatu#612, kvkgueltig#613, regkas#614, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#591,ksnam#592,ksgebdat#593,ksbehdat#594,kslz1#595,kslz2#596,kslz3#597,kslz4#598,kslz5#599,kslz6#600,kslz7#601,kslz8#602,kslz9#603,kslz10#604,kskas#605,ksgs#606,ksver#607,kasnr#608,kasgor#609,scheinart#610,behart#611,kvklesdatu#612,kvkgueltig#613,regkas#614,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_and.arbehdat
#             +- Relation spark_catalog.fidus_and.arbehdat[kspatnr#637,ksnam#638,ksgebdat#639,ksbehdat#640,kslz1#641,kslz2#642,kslz3#643,kslz4#644,kslz5#645,kslz6#646,kslz7#647,kslz8#648,kslz9#649,kslz10#650,kskas#651,ksgs#652,ksver#653,kasnr#654,kasgor#655,scheinart#656,behart#657,kvklesdatu#658,kvkgueltig#659,regkas#660,... 22 more fields] parquet
#
# Verarbeite Tabelle: fidus_and.rechkopf
# Fehler beim Laden/Joinen von fidus_and.rechkopf: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`rnr`, `t1`.`id`, `t1`.`iknr`, `t2`.`kas`, `t1`.`kasnr`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_and.rechkopf t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#716 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#684,ksnam#685,ksgebdat#686,ksbehdat#687,kslz1#688,kslz2#689,kslz3#690,kslz4#691,kslz5#692,kslz6#693,kslz7#694,kslz8#695,kslz9#696,kslz10#697,kskas#698,ksgs#699,ksver#700,kasnr#701,kasgor#702,scheinart#703,behart#704,kvklesdatu#705,kvkgueltig#706,regkas#707,versichnr#708,iknr#709,verst#710,verste#711,ktgr#712,abrart#713,abrgebiet#714,kvkl_zulnr#715,id#716,scheinid#717,praxis#718,arzt#719,abrkennz#720,abrjjq#721,uhrzeit#722,wop#723,egk#724,personengr#725,dmp#726,vschutzvon#727,kartekas#728])
#       :        +- Project [cast(kspatnr#729 as double) AS kspatnr#684, cast(ksnam#730 as string) AS ksnam#685, cast(ksgebdat#731 as string) AS ksgebdat#686, cast(ksbehdat#732 as string) AS ksbehdat#687, cast(kslz1#733 as string) AS kslz1#688, cast(kslz2#734 as string) AS kslz2#689, cast(kslz3#735 as string) AS kslz3#690, cast(kslz4#736 as string) AS kslz4#691, cast(kslz5#737 as string) AS kslz5#692, cast(kslz6#738 as string) AS kslz6#693, cast(kslz7#739 as string) AS kslz7#694, cast(kslz8#740 as string) AS kslz8#695, cast(kslz9#741 as string) AS kslz9#696, cast(kslz10#742 as string) AS kslz10#697, cast(kskas#743 as string) AS kskas#698, cast(ksgs#744 as int) AS ksgs#699, cast(ksver#745 as string) AS ksver#700, cast(kasnr#746 as double) AS kasnr#701, cast(kasgor#747 as string) AS kasgor#702, cast(scheinart#748 as string) AS scheinart#703, cast(behart#749 as double) AS behart#704, cast(kvklesdatu#750 as string) AS kvklesdatu#705, cast(kvkgueltig#751 as string) AS kvkgueltig#706, cast(regkas#752 as string) AS regkas#707, ... 21 more fields]
#       :           +- Project [kspatnr#729, ksnam#730, ksgebdat#731, ksbehdat#732, kslz1#733, kslz2#734, kslz3#735, kslz4#736, kslz5#737, kslz6#738, kslz7#739, kslz8#740, kslz9#741, kslz10#742, kskas#743, ksgs#744, ksver#745, kasnr#746, kasgor#747, scheinart#748, behart#749, kvklesdatu#750, kvkgueltig#751, regkas#752, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#729,ksnam#730,ksgebdat#731,ksbehdat#732,kslz1#733,kslz2#734,kslz3#735,kslz4#736,kslz5#737,kslz6#738,kslz7#739,kslz8#740,kslz9#741,kslz10#742,kskas#743,ksgs#744,ksver#745,kasnr#746,kasgor#747,scheinart#748,behart#749,kvklesdatu#750,kvkgueltig#751,regkas#752,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_and.rechkopf
#             +- Relation spark_catalog.fidus_and.rechkopf[rkopfid#775,scheinid#776,patnr#777,druckmark#778,rechnempf#779,rechnstell#780,rechnart#781,rnr#782,status#783,statusdat#784,zahlziel#785,mwst#786,honminder#787,rechdat#788,diagnose#789,betreff#790,fusstext#791,guid#792,kas#793,rechbetrag#794,mwstbetrag#795,exportdat#796,verst#797,rnralt#798] parquet
#
# Verarbeite Tabelle: fidus_and.rechpos
# Fehler beim Laden/Joinen von fidus_and.rechpos: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`posnr`, `t1`.`id`, `t1`.`iknr`, `t1`.`kasnr`, `t2`.`mwst`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_and.rechpos t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#832 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#800,ksnam#801,ksgebdat#802,ksbehdat#803,kslz1#804,kslz2#805,kslz3#806,kslz4#807,kslz5#808,kslz6#809,kslz7#810,kslz8#811,kslz9#812,kslz10#813,kskas#814,ksgs#815,ksver#816,kasnr#817,kasgor#818,scheinart#819,behart#820,kvklesdatu#821,kvkgueltig#822,regkas#823,versichnr#824,iknr#825,verst#826,verste#827,ktgr#828,abrart#829,abrgebiet#830,kvkl_zulnr#831,id#832,scheinid#833,praxis#834,arzt#835,abrkennz#836,abrjjq#837,uhrzeit#838,wop#839,egk#840,personengr#841,dmp#842,vschutzvon#843,kartekas#844])
#       :        +- Project [cast(kspatnr#845 as double) AS kspatnr#800, cast(ksnam#846 as string) AS ksnam#801, cast(ksgebdat#847 as string) AS ksgebdat#802, cast(ksbehdat#848 as string) AS ksbehdat#803, cast(kslz1#849 as string) AS kslz1#804, cast(kslz2#850 as string) AS kslz2#805, cast(kslz3#851 as string) AS kslz3#806, cast(kslz4#852 as string) AS kslz4#807, cast(kslz5#853 as string) AS kslz5#808, cast(kslz6#854 as string) AS kslz6#809, cast(kslz7#855 as string) AS kslz7#810, cast(kslz8#856 as string) AS kslz8#811, cast(kslz9#857 as string) AS kslz9#812, cast(kslz10#858 as string) AS kslz10#813, cast(kskas#859 as string) AS kskas#814, cast(ksgs#860 as int) AS ksgs#815, cast(ksver#861 as string) AS ksver#816, cast(kasnr#862 as double) AS kasnr#817, cast(kasgor#863 as string) AS kasgor#818, cast(scheinart#864 as string) AS scheinart#819, cast(behart#865 as double) AS behart#820, cast(kvklesdatu#866 as string) AS kvklesdatu#821, cast(kvkgueltig#867 as string) AS kvkgueltig#822, cast(regkas#868 as string) AS regkas#823, ... 21 more fields]
#       :           +- Project [kspatnr#845, ksnam#846, ksgebdat#847, ksbehdat#848, kslz1#849, kslz2#850, kslz3#851, kslz4#852, kslz5#853, kslz6#854, kslz7#855, kslz8#856, kslz9#857, kslz10#858, kskas#859, ksgs#860, ksver#861, kasnr#862, kasgor#863, scheinart#864, behart#865, kvklesdatu#866, kvkgueltig#867, regkas#868, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#845,ksnam#846,ksgebdat#847,ksbehdat#848,kslz1#849,kslz2#850,kslz3#851,kslz4#852,kslz5#853,kslz6#854,kslz7#855,kslz8#856,kslz9#857,kslz10#858,kskas#859,ksgs#860,ksver#861,kasnr#862,kasgor#863,scheinart#864,behart#865,kvklesdatu#866,kvkgueltig#867,regkas#868,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_and.rechpos
#             +- Relation spark_catalog.fidus_and.rechpos[rkopfid#891,rposid#892,posnr#893,arzt#894,leistdatum#895,leisttyp#896,leistung#897,leistbez#898,menge#899,begruend#900,einheit#901,punkte#902,preis#903,faktor#904,betrag#905,mwst#906] parquet
#
# Verarbeite Tabelle: fidus_and.ekktexte
# Fehler beim Laden/Joinen von fidus_and.ekktexte: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`nr`, `t1`.`id`, `t1`.`iknr`, `t1`.`kasnr`, `t2`.`patnr`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_and.ekktexte t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#940 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#908,ksnam#909,ksgebdat#910,ksbehdat#911,kslz1#912,kslz2#913,kslz3#914,kslz4#915,kslz5#916,kslz6#917,kslz7#918,kslz8#919,kslz9#920,kslz10#921,kskas#922,ksgs#923,ksver#924,kasnr#925,kasgor#926,scheinart#927,behart#928,kvklesdatu#929,kvkgueltig#930,regkas#931,versichnr#932,iknr#933,verst#934,verste#935,ktgr#936,abrart#937,abrgebiet#938,kvkl_zulnr#939,id#940,scheinid#941,praxis#942,arzt#943,abrkennz#944,abrjjq#945,uhrzeit#946,wop#947,egk#948,personengr#949,dmp#950,vschutzvon#951,kartekas#952])
#       :        +- Project [cast(kspatnr#953 as double) AS kspatnr#908, cast(ksnam#954 as string) AS ksnam#909, cast(ksgebdat#955 as string) AS ksgebdat#910, cast(ksbehdat#956 as string) AS ksbehdat#911, cast(kslz1#957 as string) AS kslz1#912, cast(kslz2#958 as string) AS kslz2#913, cast(kslz3#959 as string) AS kslz3#914, cast(kslz4#960 as string) AS kslz4#915, cast(kslz5#961 as string) AS kslz5#916, cast(kslz6#962 as string) AS kslz6#917, cast(kslz7#963 as string) AS kslz7#918, cast(kslz8#964 as string) AS kslz8#919, cast(kslz9#965 as string) AS kslz9#920, cast(kslz10#966 as string) AS kslz10#921, cast(kskas#967 as string) AS kskas#922, cast(ksgs#968 as int) AS ksgs#923, cast(ksver#969 as string) AS ksver#924, cast(kasnr#970 as double) AS kasnr#925, cast(kasgor#971 as string) AS kasgor#926, cast(scheinart#972 as string) AS scheinart#927, cast(behart#973 as double) AS behart#928, cast(kvklesdatu#974 as string) AS kvklesdatu#929, cast(kvkgueltig#975 as string) AS kvkgueltig#930, cast(regkas#976 as string) AS regkas#931, ... 21 more fields]
#       :           +- Project [kspatnr#953, ksnam#954, ksgebdat#955, ksbehdat#956, kslz1#957, kslz2#958, kslz3#959, kslz4#960, kslz5#961, kslz6#962, kslz7#963, kslz8#964, kslz9#965, kslz10#966, kskas#967, ksgs#968, ksver#969, kasnr#970, kasgor#971, scheinart#972, behart#973, kvklesdatu#974, kvkgueltig#975, regkas#976, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#953,ksnam#954,ksgebdat#955,ksbehdat#956,kslz1#957,kslz2#958,kslz3#959,kslz4#960,kslz5#961,kslz6#962,kslz7#963,kslz8#964,kslz9#965,kslz10#966,kskas#967,ksgs#968,ksver#969,kasnr#970,kasgor#971,scheinart#972,behart#973,kvklesdatu#974,kvkgueltig#975,regkas#976,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_and.ekktexte
#             +- Relation spark_catalog.fidus_and.ekktexte[patnr#999,datum#1000,nr#1001,fduschl#1002,inhalt#1003] parquet
#
# Verarbeite Tabelle: fidus_and.ckeytabs
# Fehler beim Laden/Joinen von fidus_and.ckeytabs: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`bez`, `t1`.`id`, `t1`.`iknr`, `t1`.`kasnr`, `t1`.`dmp`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_and.ckeytabs t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#1037 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#1005,ksnam#1006,ksgebdat#1007,ksbehdat#1008,kslz1#1009,kslz2#1010,kslz3#1011,kslz4#1012,kslz5#1013,kslz6#1014,kslz7#1015,kslz8#1016,kslz9#1017,kslz10#1018,kskas#1019,ksgs#1020,ksver#1021,kasnr#1022,kasgor#1023,scheinart#1024,behart#1025,kvklesdatu#1026,kvkgueltig#1027,regkas#1028,versichnr#1029,iknr#1030,verst#1031,verste#1032,ktgr#1033,abrart#1034,abrgebiet#1035,kvkl_zulnr#1036,id#1037,scheinid#1038,praxis#1039,arzt#1040,abrkennz#1041,abrjjq#1042,uhrzeit#1043,wop#1044,egk#1045,personengr#1046,dmp#1047,vschutzvon#1048,kartekas#1049])
#       :        +- Project [cast(kspatnr#1050 as double) AS kspatnr#1005, cast(ksnam#1051 as string) AS ksnam#1006, cast(ksgebdat#1052 as string) AS ksgebdat#1007, cast(ksbehdat#1053 as string) AS ksbehdat#1008, cast(kslz1#1054 as string) AS kslz1#1009, cast(kslz2#1055 as string) AS kslz2#1010, cast(kslz3#1056 as string) AS kslz3#1011, cast(kslz4#1057 as string) AS kslz4#1012, cast(kslz5#1058 as string) AS kslz5#1013, cast(kslz6#1059 as string) AS kslz6#1014, cast(kslz7#1060 as string) AS kslz7#1015, cast(kslz8#1061 as string) AS kslz8#1016, cast(kslz9#1062 as string) AS kslz9#1017, cast(kslz10#1063 as string) AS kslz10#1018, cast(kskas#1064 as string) AS kskas#1019, cast(ksgs#1065 as int) AS ksgs#1020, cast(ksver#1066 as string) AS ksver#1021, cast(kasnr#1067 as double) AS kasnr#1022, cast(kasgor#1068 as string) AS kasgor#1023, cast(scheinart#1069 as string) AS scheinart#1024, cast(behart#1070 as double) AS behart#1025, cast(kvklesdatu#1071 as string) AS kvklesdatu#1026, cast(kvkgueltig#1072 as string) AS kvkgueltig#1027, cast(regkas#1073 as string) AS regkas#1028, ... 21 more fields]
#       :           +- Project [kspatnr#1050, ksnam#1051, ksgebdat#1052, ksbehdat#1053, kslz1#1054, kslz2#1055, kslz3#1056, kslz4#1057, kslz5#1058, kslz6#1059, kslz7#1060, kslz8#1061, kslz9#1062, kslz10#1063, kskas#1064, ksgs#1065, ksver#1066, kasnr#1067, kasgor#1068, scheinart#1069, behart#1070, kvklesdatu#1071, kvkgueltig#1072, regkas#1073, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#1050,ksnam#1051,ksgebdat#1052,ksbehdat#1053,kslz1#1054,kslz2#1055,kslz3#1056,kslz4#1057,kslz5#1058,kslz6#1059,kslz7#1060,kslz8#1061,kslz9#1062,kslz10#1063,kskas#1064,ksgs#1065,ksver#1066,kasnr#1067,kasgor#1068,scheinart#1069,behart#1070,kvklesdatu#1071,kvkgueltig#1072,regkas#1073,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_and.ckeytabs
#             +- Relation spark_catalog.fidus_and.ckeytabs[objekt#1096,bez#1097,schluessel#1098,langtext#1099,rechnen#1100] parquet
#
# Verarbeite Tabelle: fidus_and.patinfo
# Fehler beim Laden/Joinen von fidus_and.patinfo: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t1`.`id`, `t1`.`iknr`, `t1`.`kasnr`, `t2`.`patnr`, `t2`.`schl`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_and.patinfo t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#1134 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#1102,ksnam#1103,ksgebdat#1104,ksbehdat#1105,kslz1#1106,kslz2#1107,kslz3#1108,kslz4#1109,kslz5#1110,kslz6#1111,kslz7#1112,kslz8#1113,kslz9#1114,kslz10#1115,kskas#1116,ksgs#1117,ksver#1118,kasnr#1119,kasgor#1120,scheinart#1121,behart#1122,kvklesdatu#1123,kvkgueltig#1124,regkas#1125,versichnr#1126,iknr#1127,verst#1128,verste#1129,ktgr#1130,abrart#1131,abrgebiet#1132,kvkl_zulnr#1133,id#1134,scheinid#1135,praxis#1136,arzt#1137,abrkennz#1138,abrjjq#1139,uhrzeit#1140,wop#1141,egk#1142,personengr#1143,dmp#1144,vschutzvon#1145,kartekas#1146])
#       :        +- Project [cast(kspatnr#1147 as double) AS kspatnr#1102, cast(ksnam#1148 as string) AS ksnam#1103, cast(ksgebdat#1149 as string) AS ksgebdat#1104, cast(ksbehdat#1150 as string) AS ksbehdat#1105, cast(kslz1#1151 as string) AS kslz1#1106, cast(kslz2#1152 as string) AS kslz2#1107, cast(kslz3#1153 as string) AS kslz3#1108, cast(kslz4#1154 as string) AS kslz4#1109, cast(kslz5#1155 as string) AS kslz5#1110, cast(kslz6#1156 as string) AS kslz6#1111, cast(kslz7#1157 as string) AS kslz7#1112, cast(kslz8#1158 as string) AS kslz8#1113, cast(kslz9#1159 as string) AS kslz9#1114, cast(kslz10#1160 as string) AS kslz10#1115, cast(kskas#1161 as string) AS kskas#1116, cast(ksgs#1162 as int) AS ksgs#1117, cast(ksver#1163 as string) AS ksver#1118, cast(kasnr#1164 as double) AS kasnr#1119, cast(kasgor#1165 as string) AS kasgor#1120, cast(scheinart#1166 as string) AS scheinart#1121, cast(behart#1167 as double) AS behart#1122, cast(kvklesdatu#1168 as string) AS kvklesdatu#1123, cast(kvkgueltig#1169 as string) AS kvkgueltig#1124, cast(regkas#1170 as string) AS regkas#1125, ... 21 more fields]
#       :           +- Project [kspatnr#1147, ksnam#1148, ksgebdat#1149, ksbehdat#1150, kslz1#1151, kslz2#1152, kslz3#1153, kslz4#1154, kslz5#1155, kslz6#1156, kslz7#1157, kslz8#1158, kslz9#1159, kslz10#1160, kskas#1161, ksgs#1162, ksver#1163, kasnr#1164, kasgor#1165, scheinart#1166, behart#1167, kvklesdatu#1168, kvkgueltig#1169, regkas#1170, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#1147,ksnam#1148,ksgebdat#1149,ksbehdat#1150,kslz1#1151,kslz2#1152,kslz3#1153,kslz4#1154,kslz5#1155,kslz6#1156,kslz7#1157,kslz8#1158,kslz9#1159,kslz10#1160,kskas#1161,ksgs#1162,ksver#1163,kasnr#1164,kasgor#1165,scheinart#1166,behart#1167,kvklesdatu#1168,kvkgueltig#1169,regkas#1170,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_and.patinfo
#             +- Relation spark_catalog.fidus_and.patinfo[patnr#1193,schl#1194,inhalt#1195] parquet
#
# Verarbeite Tabelle: fidus_hbs.behdatei
# Fehler beim Laden/Joinen von fidus_hbs.behdatei: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`id`, `t2`.`iknr`, `t2`.`kasnr`, `t2`.`dmp`, `t2`.`egk`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_hbs.behdatei t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#1229 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#1197,ksnam#1198,ksgebdat#1199,ksbehdat#1200,kslz1#1201,kslz2#1202,kslz3#1203,kslz4#1204,kslz5#1205,kslz6#1206,kslz7#1207,kslz8#1208,kslz9#1209,kslz10#1210,kskas#1211,ksgs#1212,ksver#1213,kasnr#1214,kasgor#1215,scheinart#1216,behart#1217,kvklesdatu#1218,kvkgueltig#1219,regkas#1220,versichnr#1221,iknr#1222,verst#1223,verste#1224,ktgr#1225,abrart#1226,abrgebiet#1227,kvkl_zulnr#1228,id#1229,scheinid#1230,praxis#1231,arzt#1232,abrkennz#1233,abrjjq#1234,uhrzeit#1235,wop#1236,egk#1237,personengr#1238,dmp#1239,vschutzvon#1240,kartekas#1241])
#       :        +- Project [cast(kspatnr#1242 as double) AS kspatnr#1197, cast(ksnam#1243 as string) AS ksnam#1198, cast(ksgebdat#1244 as string) AS ksgebdat#1199, cast(ksbehdat#1245 as string) AS ksbehdat#1200, cast(kslz1#1246 as string) AS kslz1#1201, cast(kslz2#1247 as string) AS kslz2#1202, cast(kslz3#1248 as string) AS kslz3#1203, cast(kslz4#1249 as string) AS kslz4#1204, cast(kslz5#1250 as string) AS kslz5#1205, cast(kslz6#1251 as string) AS kslz6#1206, cast(kslz7#1252 as string) AS kslz7#1207, cast(kslz8#1253 as string) AS kslz8#1208, cast(kslz9#1254 as string) AS kslz9#1209, cast(kslz10#1255 as string) AS kslz10#1210, cast(kskas#1256 as string) AS kskas#1211, cast(ksgs#1257 as int) AS ksgs#1212, cast(ksver#1258 as string) AS ksver#1213, cast(kasnr#1259 as double) AS kasnr#1214, cast(kasgor#1260 as string) AS kasgor#1215, cast(scheinart#1261 as string) AS scheinart#1216, cast(behart#1262 as double) AS behart#1217, cast(kvklesdatu#1263 as string) AS kvklesdatu#1218, cast(kvkgueltig#1264 as string) AS kvkgueltig#1219, cast(regkas#1265 as string) AS regkas#1220, ... 21 more fields]
#       :           +- Project [kspatnr#1242, ksnam#1243, ksgebdat#1244, ksbehdat#1245, kslz1#1246, kslz2#1247, kslz3#1248, kslz4#1249, kslz5#1250, kslz6#1251, kslz7#1252, kslz8#1253, kslz9#1254, kslz10#1255, kskas#1256, ksgs#1257, ksver#1258, kasnr#1259, kasgor#1260, scheinart#1261, behart#1262, kvklesdatu#1263, kvkgueltig#1264, regkas#1265, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#1242,ksnam#1243,ksgebdat#1244,ksbehdat#1245,kslz1#1246,kslz2#1247,kslz3#1248,kslz4#1249,kslz5#1250,kslz6#1251,kslz7#1252,kslz8#1253,kslz9#1254,kslz10#1255,kskas#1256,ksgs#1257,ksver#1258,kasnr#1259,kasgor#1260,scheinart#1261,behart#1262,kvklesdatu#1263,kvkgueltig#1264,regkas#1265,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_hbs.behdatei
#             +- Relation spark_catalog.fidus_hbs.behdatei[kspatnr#1288,ksnam#1289,ksgebdat#1290,ksbehdat#1291,kslz1#1292,kslz2#1293,kslz3#1294,kslz4#1295,kslz5#1296,kslz6#1297,kslz7#1298,kslz8#1299,kslz9#1300,kslz10#1301,kskas#1302,ksgs#1303,ksver#1304,kasnr#1305,kasgor#1306,scheinart#1307,behart#1308,kvklesdatu#1309,kvkgueltig#1310,regkas#1311,... 21 more fields] parquet
#
# Verarbeite Tabelle: fidus_hbs.praxarzt
# Fehler beim Laden/Joinen von fidus_hbs.praxarzt: [RECURSIVE_VIEW] Recursive view `joined_view` detected (cycle: `joined_view` -> `joined_view`).
# Verarbeite Tabelle: fidus_hbs.patdat
# Fehler beim Laden/Joinen von fidus_hbs.patdat: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`kasnr`, `t2`.`stra`, `t2`.`akm`, `t2`.`dmp`, `t2`.`egk`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_hbs.patdat t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#1498 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#1466,ksnam#1467,ksgebdat#1468,ksbehdat#1469,kslz1#1470,kslz2#1471,kslz3#1472,kslz4#1473,kslz5#1474,kslz6#1475,kslz7#1476,kslz8#1477,kslz9#1478,kslz10#1479,kskas#1480,ksgs#1481,ksver#1482,kasnr#1483,kasgor#1484,scheinart#1485,behart#1486,kvklesdatu#1487,kvkgueltig#1488,regkas#1489,versichnr#1490,iknr#1491,verst#1492,verste#1493,ktgr#1494,abrart#1495,abrgebiet#1496,kvkl_zulnr#1497,id#1498,scheinid#1499,praxis#1500,arzt#1501,abrkennz#1502,abrjjq#1503,uhrzeit#1504,wop#1505,egk#1506,personengr#1507,dmp#1508,vschutzvon#1509,kartekas#1510])
#       :        +- Project [cast(kspatnr#1511 as double) AS kspatnr#1466, cast(ksnam#1512 as string) AS ksnam#1467, cast(ksgebdat#1513 as string) AS ksgebdat#1468, cast(ksbehdat#1514 as string) AS ksbehdat#1469, cast(kslz1#1515 as string) AS kslz1#1470, cast(kslz2#1516 as string) AS kslz2#1471, cast(kslz3#1517 as string) AS kslz3#1472, cast(kslz4#1518 as string) AS kslz4#1473, cast(kslz5#1519 as string) AS kslz5#1474, cast(kslz6#1520 as string) AS kslz6#1475, cast(kslz7#1521 as string) AS kslz7#1476, cast(kslz8#1522 as string) AS kslz8#1477, cast(kslz9#1523 as string) AS kslz9#1478, cast(kslz10#1524 as string) AS kslz10#1479, cast(kskas#1525 as string) AS kskas#1480, cast(ksgs#1526 as int) AS ksgs#1481, cast(ksver#1527 as string) AS ksver#1482, cast(kasnr#1528 as double) AS kasnr#1483, cast(kasgor#1529 as string) AS kasgor#1484, cast(scheinart#1530 as string) AS scheinart#1485, cast(behart#1531 as double) AS behart#1486, cast(kvklesdatu#1532 as string) AS kvklesdatu#1487, cast(kvkgueltig#1533 as string) AS kvkgueltig#1488, cast(regkas#1534 as string) AS regkas#1489, ... 21 more fields]
#       :           +- Project [kspatnr#1511, ksnam#1512, ksgebdat#1513, ksbehdat#1514, kslz1#1515, kslz2#1516, kslz3#1517, kslz4#1518, kslz5#1519, kslz6#1520, kslz7#1521, kslz8#1522, kslz9#1523, kslz10#1524, kskas#1525, ksgs#1526, ksver#1527, kasnr#1528, kasgor#1529, scheinart#1530, behart#1531, kvklesdatu#1532, kvkgueltig#1533, regkas#1534, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#1511,ksnam#1512,ksgebdat#1513,ksbehdat#1514,kslz1#1515,kslz2#1516,kslz3#1517,kslz4#1518,kslz5#1519,kslz6#1520,kslz7#1521,kslz8#1522,kslz9#1523,kslz10#1524,kskas#1525,ksgs#1526,ksver#1527,kasnr#1528,kasgor#1529,scheinart#1530,behart#1531,kvklesdatu#1532,kvkgueltig#1533,regkas#1534,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_hbs.patdat
#             +- Relation spark_catalog.fidus_hbs.patdat[patnr#1557,titel#1558,name#1559,vname#1560,ges#1561,geb#1562,stra#1563,lkz#1564,plz#1565,ort#1566,remnr#1567,vernr#1568,ledat#1569,arbeit#1570,arbplz#1571,arbort#1572,verst#1573,verste#1574,kas#1575,kasort#1576,kasnr#1577,kasgor#1578,kvkgueltig#1579,kvklesdatu#1580,... 34 more fields] parquet
#
# Verarbeite Tabelle: fidus_hbs.adrver
# Fehler beim Laden/Joinen von fidus_hbs.adrver: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`adrbsnr`, `t2`.`adrnr`, `t1`.`id`, `t1`.`iknr`, `t1`.`kasnr`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_hbs.adrver t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#1648 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#1616,ksnam#1617,ksgebdat#1618,ksbehdat#1619,kslz1#1620,kslz2#1621,kslz3#1622,kslz4#1623,kslz5#1624,kslz6#1625,kslz7#1626,kslz8#1627,kslz9#1628,kslz10#1629,kskas#1630,ksgs#1631,ksver#1632,kasnr#1633,kasgor#1634,scheinart#1635,behart#1636,kvklesdatu#1637,kvkgueltig#1638,regkas#1639,versichnr#1640,iknr#1641,verst#1642,verste#1643,ktgr#1644,abrart#1645,abrgebiet#1646,kvkl_zulnr#1647,id#1648,scheinid#1649,praxis#1650,arzt#1651,abrkennz#1652,abrjjq#1653,uhrzeit#1654,wop#1655,egk#1656,personengr#1657,dmp#1658,vschutzvon#1659,kartekas#1660])
#       :        +- Project [cast(kspatnr#1661 as double) AS kspatnr#1616, cast(ksnam#1662 as string) AS ksnam#1617, cast(ksgebdat#1663 as string) AS ksgebdat#1618, cast(ksbehdat#1664 as string) AS ksbehdat#1619, cast(kslz1#1665 as string) AS kslz1#1620, cast(kslz2#1666 as string) AS kslz2#1621, cast(kslz3#1667 as string) AS kslz3#1622, cast(kslz4#1668 as string) AS kslz4#1623, cast(kslz5#1669 as string) AS kslz5#1624, cast(kslz6#1670 as string) AS kslz6#1625, cast(kslz7#1671 as string) AS kslz7#1626, cast(kslz8#1672 as string) AS kslz8#1627, cast(kslz9#1673 as string) AS kslz9#1628, cast(kslz10#1674 as string) AS kslz10#1629, cast(kskas#1675 as string) AS kskas#1630, cast(ksgs#1676 as int) AS ksgs#1631, cast(ksver#1677 as string) AS ksver#1632, cast(kasnr#1678 as double) AS kasnr#1633, cast(kasgor#1679 as string) AS kasgor#1634, cast(scheinart#1680 as string) AS scheinart#1635, cast(behart#1681 as double) AS behart#1636, cast(kvklesdatu#1682 as string) AS kvklesdatu#1637, cast(kvkgueltig#1683 as string) AS kvkgueltig#1638, cast(regkas#1684 as string) AS regkas#1639, ... 21 more fields]
#       :           +- Project [kspatnr#1661, ksnam#1662, ksgebdat#1663, ksbehdat#1664, kslz1#1665, kslz2#1666, kslz3#1667, kslz4#1668, kslz5#1669, kslz6#1670, kslz7#1671, kslz8#1672, kslz9#1673, kslz10#1674, kskas#1675, ksgs#1676, ksver#1677, kasnr#1678, kasgor#1679, scheinart#1680, behart#1681, kvklesdatu#1682, kvkgueltig#1683, regkas#1684, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#1661,ksnam#1662,ksgebdat#1663,ksbehdat#1664,kslz1#1665,kslz2#1666,kslz3#1667,kslz4#1668,kslz5#1669,kslz6#1670,kslz7#1671,kslz8#1672,kslz9#1673,kslz10#1674,kskas#1675,ksgs#1676,ksver#1677,kasnr#1678,kasgor#1679,scheinart#1680,behart#1681,kvklesdatu#1682,kvkgueltig#1683,regkas#1684,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_hbs.adrver
#             +- Relation spark_catalog.fidus_hbs.adrver[adrnr#1707,adrtit#1708,adrnam#1709,adrvor#1710,adrges#1711,adrbez#1712,adrstr#1713,adrlkz#1714,adrplz#1715,adrort#1716,adrtel#1717,adrfax#1718,adranr#1719,adrna2#1720,adrgs2#1721,adrmerkmal#1722,adrbsnr#1723,adrlanr#1724,email#1725] parquet
#
# Verarbeite Tabelle: fidus_hbs.begrun
# Fehler beim Laden/Joinen von fidus_hbs.begrun: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`beg`, `t2`.`blen`, `t2`.`id`, `t2`.`kasnr`, `t1`.`id`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_hbs.begrun t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#1759 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#1727,ksnam#1728,ksgebdat#1729,ksbehdat#1730,kslz1#1731,kslz2#1732,kslz3#1733,kslz4#1734,kslz5#1735,kslz6#1736,kslz7#1737,kslz8#1738,kslz9#1739,kslz10#1740,kskas#1741,ksgs#1742,ksver#1743,kasnr#1744,kasgor#1745,scheinart#1746,behart#1747,kvklesdatu#1748,kvkgueltig#1749,regkas#1750,versichnr#1751,iknr#1752,verst#1753,verste#1754,ktgr#1755,abrart#1756,abrgebiet#1757,kvkl_zulnr#1758,id#1759,scheinid#1760,praxis#1761,arzt#1762,abrkennz#1763,abrjjq#1764,uhrzeit#1765,wop#1766,egk#1767,personengr#1768,dmp#1769,vschutzvon#1770,kartekas#1771])
#       :        +- Project [cast(kspatnr#1772 as double) AS kspatnr#1727, cast(ksnam#1773 as string) AS ksnam#1728, cast(ksgebdat#1774 as string) AS ksgebdat#1729, cast(ksbehdat#1775 as string) AS ksbehdat#1730, cast(kslz1#1776 as string) AS kslz1#1731, cast(kslz2#1777 as string) AS kslz2#1732, cast(kslz3#1778 as string) AS kslz3#1733, cast(kslz4#1779 as string) AS kslz4#1734, cast(kslz5#1780 as string) AS kslz5#1735, cast(kslz6#1781 as string) AS kslz6#1736, cast(kslz7#1782 as string) AS kslz7#1737, cast(kslz8#1783 as string) AS kslz8#1738, cast(kslz9#1784 as string) AS kslz9#1739, cast(kslz10#1785 as string) AS kslz10#1740, cast(kskas#1786 as string) AS kskas#1741, cast(ksgs#1787 as int) AS ksgs#1742, cast(ksver#1788 as string) AS ksver#1743, cast(kasnr#1789 as double) AS kasnr#1744, cast(kasgor#1790 as string) AS kasgor#1745, cast(scheinart#1791 as string) AS scheinart#1746, cast(behart#1792 as double) AS behart#1747, cast(kvklesdatu#1793 as string) AS kvklesdatu#1748, cast(kvkgueltig#1794 as string) AS kvkgueltig#1749, cast(regkas#1795 as string) AS regkas#1750, ... 21 more fields]
#       :           +- Project [kspatnr#1772, ksnam#1773, ksgebdat#1774, ksbehdat#1775, kslz1#1776, kslz2#1777, kslz3#1778, kslz4#1779, kslz5#1780, kslz6#1781, kslz7#1782, kslz8#1783, kslz9#1784, kslz10#1785, kskas#1786, ksgs#1787, ksver#1788, kasnr#1789, kasgor#1790, scheinart#1791, behart#1792, kvklesdatu#1793, kvkgueltig#1794, regkas#1795, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#1772,ksnam#1773,ksgebdat#1774,ksbehdat#1775,kslz1#1776,kslz2#1777,kslz3#1778,kslz4#1779,kslz5#1780,kslz6#1781,kslz7#1782,kslz8#1783,kslz9#1784,kslz10#1785,kskas#1786,ksgs#1787,ksver#1788,kasnr#1789,kasgor#1790,scheinart#1791,behart#1792,kvklesdatu#1793,kvkgueltig#1794,regkas#1795,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_hbs.begrun
#             +- Relation spark_catalog.fidus_hbs.begrun[kspatnr#1818,kasnr#1819,jjq#1820,scheinart#1821,begruendg1#1822,beg#1823,blen#1824,id#1825,suntergr#1826,abrechnung#1827,abrdatum#1828] parquet
#
# Verarbeite Tabelle: fidus_hbs.arbehdat
# Fehler beim Laden/Joinen von fidus_hbs.arbehdat: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`id`, `t2`.`iknr`, `t2`.`kasnr`, `t2`.`dmp`, `t2`.`egk`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_hbs.arbehdat t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#1862 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#1830,ksnam#1831,ksgebdat#1832,ksbehdat#1833,kslz1#1834,kslz2#1835,kslz3#1836,kslz4#1837,kslz5#1838,kslz6#1839,kslz7#1840,kslz8#1841,kslz9#1842,kslz10#1843,kskas#1844,ksgs#1845,ksver#1846,kasnr#1847,kasgor#1848,scheinart#1849,behart#1850,kvklesdatu#1851,kvkgueltig#1852,regkas#1853,versichnr#1854,iknr#1855,verst#1856,verste#1857,ktgr#1858,abrart#1859,abrgebiet#1860,kvkl_zulnr#1861,id#1862,scheinid#1863,praxis#1864,arzt#1865,abrkennz#1866,abrjjq#1867,uhrzeit#1868,wop#1869,egk#1870,personengr#1871,dmp#1872,vschutzvon#1873,kartekas#1874])
#       :        +- Project [cast(kspatnr#1875 as double) AS kspatnr#1830, cast(ksnam#1876 as string) AS ksnam#1831, cast(ksgebdat#1877 as string) AS ksgebdat#1832, cast(ksbehdat#1878 as string) AS ksbehdat#1833, cast(kslz1#1879 as string) AS kslz1#1834, cast(kslz2#1880 as string) AS kslz2#1835, cast(kslz3#1881 as string) AS kslz3#1836, cast(kslz4#1882 as string) AS kslz4#1837, cast(kslz5#1883 as string) AS kslz5#1838, cast(kslz6#1884 as string) AS kslz6#1839, cast(kslz7#1885 as string) AS kslz7#1840, cast(kslz8#1886 as string) AS kslz8#1841, cast(kslz9#1887 as string) AS kslz9#1842, cast(kslz10#1888 as string) AS kslz10#1843, cast(kskas#1889 as string) AS kskas#1844, cast(ksgs#1890 as int) AS ksgs#1845, cast(ksver#1891 as string) AS ksver#1846, cast(kasnr#1892 as double) AS kasnr#1847, cast(kasgor#1893 as string) AS kasgor#1848, cast(scheinart#1894 as string) AS scheinart#1849, cast(behart#1895 as double) AS behart#1850, cast(kvklesdatu#1896 as string) AS kvklesdatu#1851, cast(kvkgueltig#1897 as string) AS kvkgueltig#1852, cast(regkas#1898 as string) AS regkas#1853, ... 21 more fields]
#       :           +- Project [kspatnr#1875, ksnam#1876, ksgebdat#1877, ksbehdat#1878, kslz1#1879, kslz2#1880, kslz3#1881, kslz4#1882, kslz5#1883, kslz6#1884, kslz7#1885, kslz8#1886, kslz9#1887, kslz10#1888, kskas#1889, ksgs#1890, ksver#1891, kasnr#1892, kasgor#1893, scheinart#1894, behart#1895, kvklesdatu#1896, kvkgueltig#1897, regkas#1898, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
# ...
#       :           +- Project [kspatnr#9715, ksnam#9716, ksgebdat#9717, ksbehdat#9718, kslz1#9719, kslz2#9720, kslz3#9721, kslz4#9722, kslz5#9723, kslz6#9724, kslz7#9725, kslz8#9726, kslz9#9727, kslz10#9728, kskas#9729, ksgs#9730, ksver#9731, kasnr#9732, kasgor#9733, scheinart#9734, behart#9735, kvklesdatu#9736, kvkgueltig#9737, regkas#9738, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#9715,ksnam#9716,ksgebdat#9717,ksbehdat#9718,kslz1#9719,kslz2#9720,kslz3#9721,kslz4#9722,kslz5#9723,kslz6#9724,kslz7#9725,kslz8#9726,kslz9#9727,kslz10#9728,kskas#9729,ksgs#9730,ksver#9731,kasnr#9732,kasgor#9733,scheinart#9734,behart#9735,kvklesdatu#9736,kvkgueltig#9737,regkas#9738,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_wrw.rechkopf
#             +- Relation spark_catalog.fidus_wrw.rechkopf[rkopfid#9761,scheinid#9762,patnr#9763,druckmark#9764,rechnempf#9765,rechnstell#9766,rechnart#9767,rnr#9768,status#9769,statusdat#9770,zahlziel#9771,mwst#9772,honminder#9773,rechdat#9774,diagnose#9775,betreff#9776,fusstext#9777,guid#9778,kas#9779,rechbetrag#9780,mwstbetrag#9781,exportdat#9782,verst#9783,rnralt#9784] parquet
#
# Verarbeite Tabelle: fidus_wrw.rechpos
# Fehler beim Laden/Joinen von fidus_wrw.rechpos: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`posnr`, `t1`.`id`, `t1`.`iknr`, `t1`.`kasnr`, `t2`.`mwst`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_wrw.rechpos t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#9818 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#9786,ksnam#9787,ksgebdat#9788,ksbehdat#9789,kslz1#9790,kslz2#9791,kslz3#9792,kslz4#9793,kslz5#9794,kslz6#9795,kslz7#9796,kslz8#9797,kslz9#9798,kslz10#9799,kskas#9800,ksgs#9801,ksver#9802,kasnr#9803,kasgor#9804,scheinart#9805,behart#9806,kvklesdatu#9807,kvkgueltig#9808,regkas#9809,versichnr#9810,iknr#9811,verst#9812,verste#9813,ktgr#9814,abrart#9815,abrgebiet#9816,kvkl_zulnr#9817,id#9818,scheinid#9819,praxis#9820,arzt#9821,abrkennz#9822,abrjjq#9823,uhrzeit#9824,wop#9825,egk#9826,personengr#9827,dmp#9828,vschutzvon#9829,kartekas#9830])
#       :        +- Project [cast(kspatnr#9831 as double) AS kspatnr#9786, cast(ksnam#9832 as string) AS ksnam#9787, cast(ksgebdat#9833 as string) AS ksgebdat#9788, cast(ksbehdat#9834 as string) AS ksbehdat#9789, cast(kslz1#9835 as string) AS kslz1#9790, cast(kslz2#9836 as string) AS kslz2#9791, cast(kslz3#9837 as string) AS kslz3#9792, cast(kslz4#9838 as string) AS kslz4#9793, cast(kslz5#9839 as string) AS kslz5#9794, cast(kslz6#9840 as string) AS kslz6#9795, cast(kslz7#9841 as string) AS kslz7#9796, cast(kslz8#9842 as string) AS kslz8#9797, cast(kslz9#9843 as string) AS kslz9#9798, cast(kslz10#9844 as string) AS kslz10#9799, cast(kskas#9845 as string) AS kskas#9800, cast(ksgs#9846 as int) AS ksgs#9801, cast(ksver#9847 as string) AS ksver#9802, cast(kasnr#9848 as double) AS kasnr#9803, cast(kasgor#9849 as string) AS kasgor#9804, cast(scheinart#9850 as string) AS scheinart#9805, cast(behart#9851 as double) AS behart#9806, cast(kvklesdatu#9852 as string) AS kvklesdatu#9807, cast(kvkgueltig#9853 as string) AS kvkgueltig#9808, cast(regkas#9854 as string) AS regkas#9809, ... 21 more fields]
#       :           +- Project [kspatnr#9831, ksnam#9832, ksgebdat#9833, ksbehdat#9834, kslz1#9835, kslz2#9836, kslz3#9837, kslz4#9838, kslz5#9839, kslz6#9840, kslz7#9841, kslz8#9842, kslz9#9843, kslz10#9844, kskas#9845, ksgs#9846, ksver#9847, kasnr#9848, kasgor#9849, scheinart#9850, behart#9851, kvklesdatu#9852, kvkgueltig#9853, regkas#9854, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#9831,ksnam#9832,ksgebdat#9833,ksbehdat#9834,kslz1#9835,kslz2#9836,kslz3#9837,kslz4#9838,kslz5#9839,kslz6#9840,kslz7#9841,kslz8#9842,kslz9#9843,kslz10#9844,kskas#9845,ksgs#9846,ksver#9847,kasnr#9848,kasgor#9849,scheinart#9850,behart#9851,kvklesdatu#9852,kvkgueltig#9853,regkas#9854,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_wrw.rechpos
#             +- Relation spark_catalog.fidus_wrw.rechpos[rkopfid#9877,rposid#9878,posnr#9879,arzt#9880,leistdatum#9881,leisttyp#9882,leistung#9883,leistbez#9884,menge#9885,begruend#9886,einheit#9887,punkte#9888,preis#9889,faktor#9890,betrag#9891,mwst#9892] parquet
#
# Verarbeite Tabelle: fidus_wrw.ekktexte
# Fehler beim Laden/Joinen von fidus_wrw.ekktexte: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`nr`, `t1`.`id`, `t1`.`iknr`, `t1`.`kasnr`, `t2`.`patnr`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_wrw.ekktexte t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#9926 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#9894,ksnam#9895,ksgebdat#9896,ksbehdat#9897,kslz1#9898,kslz2#9899,kslz3#9900,kslz4#9901,kslz5#9902,kslz6#9903,kslz7#9904,kslz8#9905,kslz9#9906,kslz10#9907,kskas#9908,ksgs#9909,ksver#9910,kasnr#9911,kasgor#9912,scheinart#9913,behart#9914,kvklesdatu#9915,kvkgueltig#9916,regkas#9917,versichnr#9918,iknr#9919,verst#9920,verste#9921,ktgr#9922,abrart#9923,abrgebiet#9924,kvkl_zulnr#9925,id#9926,scheinid#9927,praxis#9928,arzt#9929,abrkennz#9930,abrjjq#9931,uhrzeit#9932,wop#9933,egk#9934,personengr#9935,dmp#9936,vschutzvon#9937,kartekas#9938])
#       :        +- Project [cast(kspatnr#9939 as double) AS kspatnr#9894, cast(ksnam#9940 as string) AS ksnam#9895, cast(ksgebdat#9941 as string) AS ksgebdat#9896, cast(ksbehdat#9942 as string) AS ksbehdat#9897, cast(kslz1#9943 as string) AS kslz1#9898, cast(kslz2#9944 as string) AS kslz2#9899, cast(kslz3#9945 as string) AS kslz3#9900, cast(kslz4#9946 as string) AS kslz4#9901, cast(kslz5#9947 as string) AS kslz5#9902, cast(kslz6#9948 as string) AS kslz6#9903, cast(kslz7#9949 as string) AS kslz7#9904, cast(kslz8#9950 as string) AS kslz8#9905, cast(kslz9#9951 as string) AS kslz9#9906, cast(kslz10#9952 as string) AS kslz10#9907, cast(kskas#9953 as string) AS kskas#9908, cast(ksgs#9954 as int) AS ksgs#9909, cast(ksver#9955 as string) AS ksver#9910, cast(kasnr#9956 as double) AS kasnr#9911, cast(kasgor#9957 as string) AS kasgor#9912, cast(scheinart#9958 as string) AS scheinart#9913, cast(behart#9959 as double) AS behart#9914, cast(kvklesdatu#9960 as string) AS kvklesdatu#9915, cast(kvkgueltig#9961 as string) AS kvkgueltig#9916, cast(regkas#9962 as string) AS regkas#9917, ... 21 more fields]
#       :           +- Project [kspatnr#9939, ksnam#9940, ksgebdat#9941, ksbehdat#9942, kslz1#9943, kslz2#9944, kslz3#9945, kslz4#9946, kslz5#9947, kslz6#9948, kslz7#9949, kslz8#9950, kslz9#9951, kslz10#9952, kskas#9953, ksgs#9954, ksver#9955, kasnr#9956, kasgor#9957, scheinart#9958, behart#9959, kvklesdatu#9960, kvkgueltig#9961, regkas#9962, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#9939,ksnam#9940,ksgebdat#9941,ksbehdat#9942,kslz1#9943,kslz2#9944,kslz3#9945,kslz4#9946,kslz5#9947,kslz6#9948,kslz7#9949,kslz8#9950,kslz9#9951,kslz10#9952,kskas#9953,ksgs#9954,ksver#9955,kasnr#9956,kasgor#9957,scheinart#9958,behart#9959,kvklesdatu#9960,kvkgueltig#9961,regkas#9962,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_wrw.ekktexte
#             +- Relation spark_catalog.fidus_wrw.ekktexte[patnr#9985,datum#9986,nr#9987,fduschl#9988,inhalt#9989] parquet
#
# Verarbeite Tabelle: fidus_wrw.ckeytabs
# Fehler beim Laden/Joinen von fidus_wrw.ckeytabs: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t2`.`bez`, `t1`.`id`, `t1`.`iknr`, `t1`.`kasnr`, `t1`.`dmp`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_wrw.ckeytabs t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#10023 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#9991,ksnam#9992,ksgebdat#9993,ksbehdat#9994,kslz1#9995,kslz2#9996,kslz3#9997,kslz4#9998,kslz5#9999,kslz6#10000,kslz7#10001,kslz8#10002,kslz9#10003,kslz10#10004,kskas#10005,ksgs#10006,ksver#10007,kasnr#10008,kasgor#10009,scheinart#10010,behart#10011,kvklesdatu#10012,kvkgueltig#10013,regkas#10014,versichnr#10015,iknr#10016,verst#10017,verste#10018,ktgr#10019,abrart#10020,abrgebiet#10021,kvkl_zulnr#10022,id#10023,scheinid#10024,praxis#10025,arzt#10026,abrkennz#10027,abrjjq#10028,uhrzeit#10029,wop#10030,egk#10031,personengr#10032,dmp#10033,vschutzvon#10034,kartekas#10035])
#       :        +- Project [cast(kspatnr#10036 as double) AS kspatnr#9991, cast(ksnam#10037 as string) AS ksnam#9992, cast(ksgebdat#10038 as string) AS ksgebdat#9993, cast(ksbehdat#10039 as string) AS ksbehdat#9994, cast(kslz1#10040 as string) AS kslz1#9995, cast(kslz2#10041 as string) AS kslz2#9996, cast(kslz3#10042 as string) AS kslz3#9997, cast(kslz4#10043 as string) AS kslz4#9998, cast(kslz5#10044 as string) AS kslz5#9999, cast(kslz6#10045 as string) AS kslz6#10000, cast(kslz7#10046 as string) AS kslz7#10001, cast(kslz8#10047 as string) AS kslz8#10002, cast(kslz9#10048 as string) AS kslz9#10003, cast(kslz10#10049 as string) AS kslz10#10004, cast(kskas#10050 as string) AS kskas#10005, cast(ksgs#10051 as int) AS ksgs#10006, cast(ksver#10052 as string) AS ksver#10007, cast(kasnr#10053 as double) AS kasnr#10008, cast(kasgor#10054 as string) AS kasgor#10009, cast(scheinart#10055 as string) AS scheinart#10010, cast(behart#10056 as double) AS behart#10011, cast(kvklesdatu#10057 as string) AS kvklesdatu#10012, cast(kvkgueltig#10058 as string) AS kvkgueltig#10013, cast(regkas#10059 as string) AS regkas#10014, ... 21 more fields]
#       :           +- Project [kspatnr#10036, ksnam#10037, ksgebdat#10038, ksbehdat#10039, kslz1#10040, kslz2#10041, kslz3#10042, kslz4#10043, kslz5#10044, kslz6#10045, kslz7#10046, kslz8#10047, kslz9#10048, kslz10#10049, kskas#10050, ksgs#10051, ksver#10052, kasnr#10053, kasgor#10054, scheinart#10055, behart#10056, kvklesdatu#10057, kvkgueltig#10058, regkas#10059, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#10036,ksnam#10037,ksgebdat#10038,ksbehdat#10039,kslz1#10040,kslz2#10041,kslz3#10042,kslz4#10043,kslz5#10044,kslz6#10045,kslz7#10046,kslz8#10047,kslz9#10048,kslz10#10049,kskas#10050,ksgs#10051,ksver#10052,kasnr#10053,kasgor#10054,scheinart#10055,behart#10056,kvklesdatu#10057,kvkgueltig#10058,regkas#10059,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_wrw.ckeytabs
#             +- Relation spark_catalog.fidus_wrw.ckeytabs[objekt#10082,bez#10083,schluessel#10084,langtext#10085,rechnen#10086] parquet
#
# Verarbeite Tabelle: fidus_wrw.patinfo
# Fehler beim Laden/Joinen von fidus_wrw.patinfo: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t2`.`bsnr` cannot be resolved. Did you mean one of the following? [`t1`.`id`, `t1`.`iknr`, `t1`.`kasnr`, `t2`.`patnr`, `t2`.`schl`].; line 6 pos 31;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_wrw.patinfo t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, (id#10120 = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [kspatnr#10088,ksnam#10089,ksgebdat#10090,ksbehdat#10091,kslz1#10092,kslz2#10093,kslz3#10094,kslz4#10095,kslz5#10096,kslz6#10097,kslz7#10098,kslz8#10099,kslz9#10100,kslz10#10101,kskas#10102,ksgs#10103,ksver#10104,kasnr#10105,kasgor#10106,scheinart#10107,behart#10108,kvklesdatu#10109,kvkgueltig#10110,regkas#10111,versichnr#10112,iknr#10113,verst#10114,verste#10115,ktgr#10116,abrart#10117,abrgebiet#10118,kvkl_zulnr#10119,id#10120,scheinid#10121,praxis#10122,arzt#10123,abrkennz#10124,abrjjq#10125,uhrzeit#10126,wop#10127,egk#10128,personengr#10129,dmp#10130,vschutzvon#10131,kartekas#10132])
#       :        +- Project [cast(kspatnr#10133 as double) AS kspatnr#10088, cast(ksnam#10134 as string) AS ksnam#10089, cast(ksgebdat#10135 as string) AS ksgebdat#10090, cast(ksbehdat#10136 as string) AS ksbehdat#10091, cast(kslz1#10137 as string) AS kslz1#10092, cast(kslz2#10138 as string) AS kslz2#10093, cast(kslz3#10139 as string) AS kslz3#10094, cast(kslz4#10140 as string) AS kslz4#10095, cast(kslz5#10141 as string) AS kslz5#10096, cast(kslz6#10142 as string) AS kslz6#10097, cast(kslz7#10143 as string) AS kslz7#10098, cast(kslz8#10144 as string) AS kslz8#10099, cast(kslz9#10145 as string) AS kslz9#10100, cast(kslz10#10146 as string) AS kslz10#10101, cast(kskas#10147 as string) AS kskas#10102, cast(ksgs#10148 as int) AS ksgs#10103, cast(ksver#10149 as string) AS ksver#10104, cast(kasnr#10150 as double) AS kasnr#10105, cast(kasgor#10151 as string) AS kasgor#10106, cast(scheinart#10152 as string) AS scheinart#10107, cast(behart#10153 as double) AS behart#10108, cast(kvklesdatu#10154 as string) AS kvklesdatu#10109, cast(kvkgueltig#10155 as string) AS kvkgueltig#10110, cast(regkas#10156 as string) AS regkas#10111, ... 21 more fields]
#       :           +- Project [kspatnr#10133, ksnam#10134, ksgebdat#10135, ksbehdat#10136, kslz1#10137, kslz2#10138, kslz3#10139, kslz4#10140, kslz5#10141, kslz6#10142, kslz7#10143, kslz8#10144, kslz9#10145, kslz10#10146, kskas#10147, ksgs#10148, ksver#10149, kasnr#10150, kasgor#10151, scheinart#10152, behart#10153, kvklesdatu#10154, kvkgueltig#10155, regkas#10156, ... 21 more fields]
#       :              +- SubqueryAlias spark_catalog.fidus_and.behdatei
#       :                 +- Relation spark_catalog.fidus_and.behdatei[kspatnr#10133,ksnam#10134,ksgebdat#10135,ksbehdat#10136,kslz1#10137,kslz2#10138,kslz3#10139,kslz4#10140,kslz5#10141,kslz6#10142,kslz7#10143,kslz8#10144,kslz9#10145,kslz10#10146,kskas#10147,ksgs#10148,ksver#10149,kasnr#10150,kasgor#10151,scheinart#10152,behart#10153,kvklesdatu#10154,kvkgueltig#10155,regkas#10156,... 21 more fields] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_wrw.patinfo
#             +- Relation spark_catalog.fidus_wrw.patinfo[patnr#10179,schl#10180,inhalt#10181] parquet

# %%
# Join der Datenbanken

# Liste der Datenbanken
databases = [
    "fidus_and",
    "fidus_hbs",
    "fidus_hrs",
    "fidus_mhw",
    "fidus_oaf",
    "fidus_sub",
    "fidus_sue",
    "fidus_wrw"
]

# Liste der Tabellennamen
tables = ["ekktexte"]

# Wir bauen die temporäre View "joined_view" schrittweise auf.
joined_view = None

# Verschachtelte Schleife: Für jede Datenbank und jede Tabelle
for db in databases:
    for tbl in tables:
        full_table_name = f"{db}.{tbl}"
        print(f"Verarbeite Tabelle: {full_table_name}")

        try:
            if joined_view is None:
                # Initialen Start: Lege die erste Tabelle als temporäre View ab
                spark.sql(f"""
                    CREATE OR REPLACE TEMP VIEW joined_view AS
                    SELECT *
                    FROM {full_table_name}
                """)
                joined_view = "joined_view"
            else:
                spark.sql(f"""
                    CREATE OR REPLACE TEMP VIEW joined_view AS
                    SELECT t1.*, t2.*
                    FROM joined_view t1
                    INNER JOIN {full_table_name} t2
                    ON t1.id = t2.bsnr
                """)
        except Exception as e:
            print(f"Fehler beim Laden/Joinen von {full_table_name}: {e}")

# Finale Abfrage aus der temporären View, die alle Spalten enthalten sollte
df_final = spark.sql("SELECT * FROM joined_view")
# Out:
# Verarbeite Tabelle: fidus_and.ekktexte
# Hive Session ID = fe080bee-99c7-452a-88a0-9ab5833c8479
# Verarbeite Tabelle: fidus_hbs.ekktexte
# Fehler beim Laden/Joinen von fidus_hbs.ekktexte: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t1`.`id` cannot be resolved. Did you mean one of the following? [`t1`.`nr`, `t2`.`nr`, `t1`.`datum`, `t2`.`datum`, `t1`.`inhalt`].; line 6 pos 23;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_hbs.ekktexte t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, ('t1.id = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [patnr#6,datum#7,nr#8,fduschl#9,inhalt#10])
#       :        +- Project [cast(patnr#11 as double) AS patnr#6, cast(datum#12 as string) AS datum#7, cast(nr#13 as double) AS nr#8, cast(fduschl#14 as string) AS fduschl#9, cast(inhalt#15 as string) AS inhalt#10]
#       :           +- Project [patnr#11, datum#12, nr#13, fduschl#14, inhalt#15]
#       :              +- SubqueryAlias spark_catalog.fidus_and.ekktexte
#       :                 +- Relation spark_catalog.fidus_and.ekktexte[patnr#11,datum#12,nr#13,fduschl#14,inhalt#15] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_hbs.ekktexte
#             +- Relation spark_catalog.fidus_hbs.ekktexte[patnr#17,datum#18,nr#19,fduschl#20,inhalt#21] parquet
#
# Verarbeite Tabelle: fidus_hrs.ekktexte
# Fehler beim Laden/Joinen von fidus_hrs.ekktexte: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t1`.`id` cannot be resolved. Did you mean one of the following? [`t1`.`nr`, `t2`.`nr`, `t1`.`datum`, `t2`.`datum`, `t1`.`inhalt`].; line 6 pos 23;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_hrs.ekktexte t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, ('t1.id = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [patnr#23,datum#24,nr#25,fduschl#26,inhalt#27])
#       :        +- Project [cast(patnr#28 as double) AS patnr#23, cast(datum#29 as string) AS datum#24, cast(nr#30 as double) AS nr#25, cast(fduschl#31 as string) AS fduschl#26, cast(inhalt#32 as string) AS inhalt#27]
#       :           +- Project [patnr#28, datum#29, nr#30, fduschl#31, inhalt#32]
#       :              +- SubqueryAlias spark_catalog.fidus_and.ekktexte
#       :                 +- Relation spark_catalog.fidus_and.ekktexte[patnr#28,datum#29,nr#30,fduschl#31,inhalt#32] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_hrs.ekktexte
#             +- Relation spark_catalog.fidus_hrs.ekktexte[patnr#34,datum#35,nr#36,fduschl#37,inhalt#38] parquet
#
# Verarbeite Tabelle: fidus_mhw.ekktexte
# Fehler beim Laden/Joinen von fidus_mhw.ekktexte: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t1`.`id` cannot be resolved. Did you mean one of the following? [`t1`.`nr`, `t2`.`nr`, `t1`.`datum`, `t2`.`datum`, `t1`.`inhalt`].; line 6 pos 23;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_mhw.ekktexte t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, ('t1.id = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [patnr#40,datum#41,nr#42,fduschl#43,inhalt#44])
#       :        +- Project [cast(patnr#45 as double) AS patnr#40, cast(datum#46 as string) AS datum#41, cast(nr#47 as double) AS nr#42, cast(fduschl#48 as string) AS fduschl#43, cast(inhalt#49 as string) AS inhalt#44]
#       :           +- Project [patnr#45, datum#46, nr#47, fduschl#48, inhalt#49]
#       :              +- SubqueryAlias spark_catalog.fidus_and.ekktexte
#       :                 +- Relation spark_catalog.fidus_and.ekktexte[patnr#45,datum#46,nr#47,fduschl#48,inhalt#49] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_mhw.ekktexte
#             +- Relation spark_catalog.fidus_mhw.ekktexte[patnr#51,datum#52,nr#53,fduschl#54,inhalt#55] parquet
#
# Verarbeite Tabelle: fidus_oaf.ekktexte
# Fehler beim Laden/Joinen von fidus_oaf.ekktexte: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t1`.`id` cannot be resolved. Did you mean one of the following? [`t1`.`nr`, `t2`.`nr`, `t1`.`datum`, `t2`.`datum`, `t1`.`inhalt`].; line 6 pos 23;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_oaf.ekktexte t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, ('t1.id = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [patnr#57,datum#58,nr#59,fduschl#60,inhalt#61])
#       :        +- Project [cast(patnr#62 as double) AS patnr#57, cast(datum#63 as string) AS datum#58, cast(nr#64 as double) AS nr#59, cast(fduschl#65 as string) AS fduschl#60, cast(inhalt#66 as string) AS inhalt#61]
#       :           +- Project [patnr#62, datum#63, nr#64, fduschl#65, inhalt#66]
#       :              +- SubqueryAlias spark_catalog.fidus_and.ekktexte
#       :                 +- Relation spark_catalog.fidus_and.ekktexte[patnr#62,datum#63,nr#64,fduschl#65,inhalt#66] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_oaf.ekktexte
#             +- Relation spark_catalog.fidus_oaf.ekktexte[patnr#68,datum#69,nr#70,fduschl#71,inhalt#72] parquet
#
# Verarbeite Tabelle: fidus_sub.ekktexte
# Fehler beim Laden/Joinen von fidus_sub.ekktexte: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t1`.`id` cannot be resolved. Did you mean one of the following? [`t1`.`nr`, `t2`.`nr`, `t1`.`datum`, `t2`.`datum`, `t1`.`inhalt`].; line 6 pos 23;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_sub.ekktexte t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, ('t1.id = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [patnr#74,datum#75,nr#76,fduschl#77,inhalt#78])
#       :        +- Project [cast(patnr#79 as double) AS patnr#74, cast(datum#80 as string) AS datum#75, cast(nr#81 as double) AS nr#76, cast(fduschl#82 as string) AS fduschl#77, cast(inhalt#83 as string) AS inhalt#78]
#       :           +- Project [patnr#79, datum#80, nr#81, fduschl#82, inhalt#83]
#       :              +- SubqueryAlias spark_catalog.fidus_and.ekktexte
#       :                 +- Relation spark_catalog.fidus_and.ekktexte[patnr#79,datum#80,nr#81,fduschl#82,inhalt#83] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_sub.ekktexte
#             +- Relation spark_catalog.fidus_sub.ekktexte[patnr#85,datum#86,nr#87,fduschl#88,inhalt#89] parquet
#
# Verarbeite Tabelle: fidus_sue.ekktexte
# Fehler beim Laden/Joinen von fidus_sue.ekktexte: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t1`.`id` cannot be resolved. Did you mean one of the following? [`t1`.`nr`, `t2`.`nr`, `t1`.`datum`, `t2`.`datum`, `t1`.`inhalt`].; line 6 pos 23;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_sue.ekktexte t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, ('t1.id = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [patnr#91,datum#92,nr#93,fduschl#94,inhalt#95])
#       :        +- Project [cast(patnr#96 as double) AS patnr#91, cast(datum#97 as string) AS datum#92, cast(nr#98 as double) AS nr#93, cast(fduschl#99 as string) AS fduschl#94, cast(inhalt#100 as string) AS inhalt#95]
#       :           +- Project [patnr#96, datum#97, nr#98, fduschl#99, inhalt#100]
#       :              +- SubqueryAlias spark_catalog.fidus_and.ekktexte
#       :                 +- Relation spark_catalog.fidus_and.ekktexte[patnr#96,datum#97,nr#98,fduschl#99,inhalt#100] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_sue.ekktexte
#             +- Relation spark_catalog.fidus_sue.ekktexte[patnr#102,datum#103,nr#104,fduschl#105,inhalt#106] parquet
#
# Verarbeite Tabelle: fidus_wrw.ekktexte
# Fehler beim Laden/Joinen von fidus_wrw.ekktexte: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `t1`.`id` cannot be resolved. Did you mean one of the following? [`t1`.`nr`, `t2`.`nr`, `t1`.`datum`, `t2`.`datum`, `t1`.`inhalt`].; line 6 pos 23;
# 'CreateViewCommand `joined_view`, SELECT t1.*, t2.*
#                     FROM joined_view t1
#                     INNER JOIN fidus_wrw.ekktexte t2
#                     ON t1.id = t2.bsnr, false, true, LocalTempView, false
# +- 'Project [t1.*, t2.*]
#    +- 'Join Inner, ('t1.id = 't2.bsnr)
#       :- SubqueryAlias t1
#       :  +- SubqueryAlias joined_view
#       :     +- View (`joined_view`, [patnr#108,datum#109,nr#110,fduschl#111,inhalt#112])
#       :        +- Project [cast(patnr#113 as double) AS patnr#108, cast(datum#114 as string) AS datum#109, cast(nr#115 as double) AS nr#110, cast(fduschl#116 as string) AS fduschl#111, cast(inhalt#117 as string) AS inhalt#112]
#       :           +- Project [patnr#113, datum#114, nr#115, fduschl#116, inhalt#117]
#       :              +- SubqueryAlias spark_catalog.fidus_and.ekktexte
#       :                 +- Relation spark_catalog.fidus_and.ekktexte[patnr#113,datum#114,nr#115,fduschl#116,inhalt#117] parquet
#       +- SubqueryAlias t2
#          +- SubqueryAlias spark_catalog.fidus_wrw.ekktexte
#             +- Relation spark_catalog.fidus_wrw.ekktexte[patnr#119,datum#120,nr#121,fduschl#122,inhalt#123] parquet

# %%
df_final.show(truncate=False)
# Out:
# +--------+--------+----------+----------+-----+-----+------+-----+-----+-----+-----+-----+-----+------+----------------------------+---------+-----+---------+------+---------+------+----------+----------+--------+---------+------------+-----+------+----+------+---------+----------+--------+--------+------+-------+--------+--------+-------+--------+--------+----------+--------+----------+---------------------+
# |kspatnr |ksnam   |ksgebdat  |ksbehdat  |kslz1|kslz2|kslz3 |kslz4|kslz5|kslz6|kslz7|kslz8|kslz9|kslz10|kskas                       |ksgs     |ksver|kasnr    |kasgor|scheinart|behart|kvklesdatu|kvkgueltig|regkas  |versichnr|iknr        |verst|verste|ktgr|abrart|abrgebiet|kvkl_zulnr|id      |scheinid|praxis|arzt   |abrkennz|abrjjq  |uhrzeit|wop     |egk     |personengr|dmp     |vschutzvon|kartekas             |
# +--------+--------+----------+----------+-----+-----+------+-----+-----+-----+-----+-----+-----+------+----------------------------+---------+-----+---------+------+---------+------+----------+----------+--------+---------+------------+-----+------+----+------+---------+----------+--------+--------+------+-------+--------+--------+-------+--------+--------+----------+--------+----------+---------------------+
# |119597.0|Zensiert|1946-01-01|2024-07-01|06212|06225|NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |AOK Bayern - Die Gesundheits|108310400| R   |7110100.0|BMÄ   |M        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.083104E8  |5.0  |0     |0   |1.0   |NULL     |Zensiert  |202576.0|153475.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Bayern           |
# |104999.0|Zensiert|1944-01-01|2024-07-02|0    |NULL |NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |BARMER                      |108380007| R   |7260100.0|EGO   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.08380007E8|5.0  |0     |0   |2.0   |NULL     |Zensiert  |202689.0|153442.0|NULL  |ZIMA017|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |BARMER               |
# |77736.0 |Zensiert|1937-01-01|2024-07-01|06212|06225|NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |AOK Bayern - Die Gesundheits|108310400| R   |7110100.0|BMÄ   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.083104E8  |5.0  |0     |0   |1.0   |NULL     |Zensiert  |202622.0|153512.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Bayern           |
# |110142.0|Zensiert|1984-01-01|2024-07-01|06211|06225|NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |BARMER                      |108380007| M   |7260100.0|EGO   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.08380007E8|1.0  |0     |0   |2.0   |NULL     |Zensiert  |202623.0|153513.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |BARMER               |
# |109209.0|Zensiert|1981-01-01|2024-07-01|06211|06225|06333 |06333|NULL |NULL |NULL |NULL |NULL |NULL  |Kaufmännische Krankenkasse -|102171012| M   |1760300.0|EGO   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.02171012E8|1.0  |0     |0   |2.0   |NULL     |Zensiert  |202624.0|153514.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |KKH                  |
# |99143.0 |Zensiert|2008-01-01|2024-07-01|06211|06225|NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |AOK Baden-Württemberg Hauptv|108018325| F   |6112500.0|BMÄ   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.08018325E8|3.0  |0     |0   |1.0   |NULL     |Zensiert  |202625.0|153515.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Heilbronn-Franken|
# |102942.0|Zensiert|2010-01-01|2024-07-01|06211|06225|NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |AOK Baden-Württemberg Hauptv|108018325| F   |6112500.0|BMÄ   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.08018325E8|3.0  |0     |0   |1.0   |NULL     |Zensiert  |202626.0|153516.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Heilbronn-Franken|
# |100975.0|Zensiert|1968-01-01|2024-07-01|06211|06225|NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |AOK Bayern - Die Gesundheits|108310400| M   |7110100.0|BMÄ   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.083104E8  |1.0  |0     |0   |1.0   |NULL     |Zensiert  |202627.0|153517.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Bayern           |
# |119605.0|Zensiert|1968-01-01|2024-07-01|06211|06225|NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |Mobil Betriebskrankenkasse  |101520078| M   |945500.0 |BMÄ   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.01520078E8|1.0  |0     |0   |1.0   |NULL     |Zensiert  |202628.0|153518.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |MOBIL KRANKENKASSE   |
# |91221.0 |Zensiert|1956-01-01|2024-07-01|06212|06225|06333 |06333|NULL |NULL |NULL |NULL |NULL |NULL  |AOK Bayern - Die Gesundheits|108310400| R   |7110100.0|BMÄ   |M        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.083104E8  |5.0  |0     |0   |1.0   |NULL     |Zensiert  |202629.0|153519.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Bayern           |
# |105663.0|Zensiert|2010-01-01|2024-07-01|06211|06225|NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |AOK Baden-Württemberg Hauptv|108018325| F   |6112500.0|BMÄ   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.08018325E8|3.0  |0     |0   |1.0   |NULL     |Zensiert  |202630.0|153520.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Heilbronn-Franken|
# |81007.0 |Zensiert|2008-01-01|2024-07-01|06211|06225|NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |AOK Bayern - Die Gesundheits|108310400| F   |7110100.0|BMÄ   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.083104E8  |3.0  |0     |0   |1.0   |NULL     |Zensiert  |202631.0|153521.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Bayern           |
# |100797.0|Zensiert|2007-01-01|2024-07-01|06211|06225|NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |AOK Baden-Württemberg Hauptv|108018325| M   |6112500.0|BMÄ   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.08018325E8|1.0  |0     |0   |1.0   |NULL     |Zensiert  |202636.0|153525.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Heilbronn-Franken|
# |119607.0|Zensiert|1982-01-01|2024-07-01|06211|06225|NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |AOK Bayern - Die Gesundheits|108310400| M   |7110100.0|BMÄ   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.083104E8  |1.0  |0     |0   |1.0   |NULL     |Zensiert  |202638.0|153527.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Bayern           |
# |119598.0|Zensiert|1960-01-01|2024-07-01|06212|06225|99873O|NULL |NULL |NULL |NULL |NULL |NULL |NULL  |AOK Baden-Württemberg Hauptv|108018564| R   |6112500.0|BMÄ   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.08018564E8|5.0  |0     |0   |1.0   |NULL     |Zensiert  |202579.0|153478.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Ostwürttemberg   |
# |117897.0|Zensiert|1950-01-01|2024-07-01|06212|06225|06336 |06337|NULL |NULL |NULL |NULL |NULL |NULL  |AOK Bayern - Die Gesundheits|108310400| R   |7110100.0|BMÄ   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.083104E8  |5.0  |0     |0   |1.0   |NULL     |Zensiert  |202577.0|153476.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Bayern           |
# |98925.0 |Zensiert|1967-01-01|2024-07-01|06211|06225|NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |BKK ProVita                 |108591499| M   |6841500.0|BMÄ   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.08591499E8|1.0  |0     |0   |1.0   |NULL     |Zensiert  |202578.0|153477.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |BKK ProVita          |
# |119599.0|Zensiert|1938-01-01|2024-07-01|06212|06225|NULL  |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |AOK Baden-Württemberg Hauptv|108018564| R   |6112500.0|BMÄ   |M        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.08018564E8|5.0  |0     |0   |1.0   |NULL     |Zensiert  |202580.0|153479.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Ostwürttemberg   |
# |73983.0 |Zensiert|1951-01-01|2024-07-01|06212|06225|06336 |06337|NULL |NULL |NULL |NULL |NULL |NULL  |AOK Bayern - Die Gesundheits|108310400| R   |7110100.0|BMÄ   |M        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.083104E8  |5.0  |0     |0   |1.0   |NULL     |Zensiert  |202583.0|153481.0|NULL  |LAVA018|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Bayern           |
# |17503.0 |Zensiert|1938-01-01|2024-07-02|06212|06336|06337 |NULL |NULL |NULL |NULL |NULL |NULL |NULL  |AOK Bayern - Die Gesundheits|108310400| R   |7110100.0|BMÄ   |O        |NULL  |2020-01-01|Zensiert  |Zensiert|Zensiert |1.083104E8  |5.0  |0     |0   |1.0   |NULL     |Zensiert  |202657.0|153539.0|NULL  |ZIMA017|Zensiert|Zensiert|NULL   |Zensiert|Zensiert|Zensiert  |Zensiert|Zensiert  |AOK Bayern           |
# +--------+--------+----------+----------+-----+-----+------+-----+-----+-----+-----+-----+-----+------+----------------------------+---------+-----+---------+------+---------+------+----------+----------+--------+---------+------------+-----+------+----+------+---------+----------+--------+--------+------+-------+--------+--------+-------+--------+--------+----------+--------+----------+---------------------+
# only showing top 20 rows

# %%
spark.sql("CREATE DATABASE IF NOT EXISTS fidus_joined")
df_final.write.format("delta").mode("overwrite").option("path", "s3a://silver/fidus/fidus_joined").saveAsTable("fidus_joined.fidus_joined")

# %%
spark.sql("show databases").show()
# Out:
# +------------+
# |   namespace|
# +------------+
# |     default|
# |   fidus_and|
# |   fidus_hbs|
# |   fidus_hrs|
# |fidus_joined|
# |   fidus_kpi|
# |   fidus_mhw|
# |   fidus_oaf|
# |   fidus_sub|
# |   fidus_sue|
# |   fidus_wrw|
# +------------+
